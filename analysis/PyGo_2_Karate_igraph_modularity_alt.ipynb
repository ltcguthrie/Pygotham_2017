# %% [markdown]
# ## Karate Club

# %% [markdown]
# ## igraph

# %%
from igraph import *

# %%
t = Graph.Read_GML("../data/karate.gml")

# %%
summary(t)
# Out:
# IGRAPH U--- 34 78 --
# + attr: id (v)

# %%
plot(t)

# %%
comms = t.community_multilevel()

plot(comms, mark_groups = True)

# %%
com = t.community_fastgreedy()

plot(com)
