# %% [markdown]
# # Import Libraries

# %%
import matplotlib as mpl
import networkx as nx
import visJS2jupyter.visJS_module
# %matplotlib inline

# %%
G = nx.read_gml('../data/dolphins.gml')

# %%
nodes = G.nodes()
edges = G.edges()

# %% [markdown]
# ## Add a node attributes to color-code by

# %%
cc = nx.clustering(G)
degree = G.degree()
bc = nx.betweenness_centrality(G)
nx.set_node_attributes(G,'clustering_coefficient',cc)
nx.set_node_attributes(G,'degree',degree)
nx.set_node_attributes(G,'betweenness_centrality',bc)

# %% [markdown]
# ## Dolphins

# %%
nx.draw(G)

# %% [markdown]
# ### Map the betweenness centrality to the node color, using matplotlib spring_r colormap

# %%
node_to_color = visJS2jupyter.visJS_module.return_node_to_color(G,field_to_map='betweenness_centrality',cmap=mpl.cm.spring_r,alpha = 1,
                                                 color_max_frac = .9,color_min_frac = .1)

# set node initial positions using networkx's spring_layout function
pos = nx.spring_layout(G)

nodes_dict = [{"id":n,"color":node_to_color[n],
               "degree":nx.degree(G,n),
              "x":pos[n][0]*1000,
              "y":pos[n][1]*1000} for n in nodes
              ]
node_map = dict(zip(nodes,range(len(nodes))))  # map to indices for source/target in edges
edges_dict = [{"source":node_map[edges[i][0]], "target":node_map[edges[i][1]], 
              "color":"gray","title":'test'} for i in range(len(edges))]

# set some network-wide styles
visJS2jupyter.visJS_module.visjs_network(nodes_dict,edges_dict,
                          node_size_multiplier=7,
                          node_size_transform = '',
                          node_color_highlight_border='red',
                          node_color_highlight_background='#D3918B',
                          node_color_hover_border='blue',
                          node_color_hover_background='#8BADD3',
                          node_font_size=25,
                          edge_arrow_to=True,
                          physics_enabled=True,
                          edge_color_highlight='#8A324E',
                          edge_color_hover='#8BADD3',
                          edge_width=3,
                          max_velocity=15,
                          min_velocity=1)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file0"];    frame.runVis([{"node_shape": "dot", "degree": 6, "title": 0, "color": "rgba(256, 214, 41, 1)", "y": 267.45231522768717, "x": 620.09662981950976, "border_width": 0, "id": 0}, {"node_shape": "dot", "degree": 8, "title": 1, "color": "rgba(256, 54, 201, 1)", "y": 699.14481266111522, "x": 758.24100406230389, "border_width": 0, "id": 1}, {"node_shape": "dot", "degree": 4, "title": 2, "color": "rgba(256, 222, 33, 1)", "y": 0.0, "x": 486.9792071748293, "border_width": 0, "id": 2}, {"node_shape": "dot", "degree": 3, "title": 3, "color": "rgba(256, 228, 27, 1)", "y": 151.59289437848014, "x": 144.28141019933804, "border_width": 0, "id": 3}, {"node_shape": "dot", "degree": 1, "title": 4, "color": "rgba(256, 230, 25, 1)", "y": 32.611986285425658, "x": 761.19650815234036, "border_width": 0, "id": 4}, {"node_shape": "dot", "degree": 4, "title": 5, "color": "rgba(256, 226, 29, 1)", "y": 1000.0, "x": 473.51034337045297, "border_width": 0, "id": 5}, {"node_shape": "dot", "degree": 6, "title": 6, "color": "rgba(256, 206, 49, 1)", "y": 996.10502688041606, "x": 549.80498801353019, "border_width": 0, "id": 6}, {"node_shape": "dot", "degree": 5, "title": 7, "color": "rgba(256, 132, 123, 1)", "y": 618.44183869416031, "x": 788.94005582720411, "border_width": 0, "id": 7}, {"node_shape": "dot", "degree": 6, "title": 8, "color": "rgba(256, 211, 44, 1)", "y": 189.52482762570529, "x": 360.81306420069745, "border_width": 0, "id": 8}, {"node_shape": "dot", "degree": 7, "title": 9, "color": "rgba(256, 213, 42, 1)", "y": 965.73540705529831, "x": 618.16128969798467, "border_width": 0, "id": 9}, {"node_shape": "dot", "degree": 5, "title": 10, "color": "rgba(256, 217, 38, 1)", "y": 102.51018038800105, "x": 726.55394639962901, "border_width": 0, "id": 10}, {"node_shape": "dot", "degree": 1, "title": 11, "color": "rgba(256, 230, 25, 1)", "y": 127.24808843125948, "x": 892.82853177340598, "border_width": 0, "id": 11}, {"node_shape": "dot", "degree": 1, "title": 12, "color": "rgba(256, 230, 25, 1)", "y": 512.69631509949909, "x": 0.0, "border_width": 0, "id": 12}, {"node_shape": "dot", "degree": 8, "title": 13, "color": "rgba(256, 186, 69, 1)", "y": 969.80157101116572, "x": 658.98745042899759, "border_width": 0, "id": 13}, {"node_shape": "dot", "degree": 12, "title": 14, "color": "rgba(256, 179, 76, 1)", "y": 297.86498206422914, "x": 309.17945616230804, "border_width": 0, "id": 14}, {"node_shape": "dot", "degree": 7, "title": 15, "color": "rgba(256, 202, 53, 1)", "y": 137.60203845669633, "x": 595.93970092963104, "border_width": 0, "id": 15}, {"node_shape": "dot", "degree": 6, "title": 16, "color": "rgba(256, 227, 28, 1)", "y": 237.75790982290206, "x": 194.49568683687761, "border_width": 0, "id": 16}, {"node_shape": "dot", "degree": 9, "title": 17, "color": "rgba(256, 136, 119, 1)", "y": 925.50800399490026, "x": 718.23541895953269, "border_width": 0, "id": 17}, {"node_shape": "dot", "degree": 7, "title": 18, "color": "rgba(256, 218, 37, 1)", "y": 46.447508538532681, "x": 551.16068588262488, "border_width": 0, "id": 18}, {"node_shape": "dot", "degree": 4, "title": 19, "color": "rgba(256, 219, 36, 1)", "y": 669.61557448280848, "x": 920.88049995277902, "border_width": 0, "id": 19}, {"node_shape": "dot", "degree": 9, "title": 20, "color": "rgba(256, 145, 110, 1)", "y": 278.84545906758621, "x": 426.78126978058305, "border_width": 0, "id": 20}, {"node_shape": "dot", "degree": 6, "title": 21, "color": "rgba(256, 219, 36, 1)", "y": 135.04314336799368, "x": 419.24667218206076, "border_width": 0, "id": 21}, {"node_shape": "dot", "degree": 1, "title": 22, "color": "rgba(256, 230, 25, 1)", "y": 970.82156998659457, "x": 436.79718947859601, "border_width": 0, "id": 22}, {"node_shape": "dot", "degree": 3, "title": 23, "color": "rgba(256, 195, 60, 1)", "y": 6.8640228921387569, "x": 619.5790478791954, "borde ...

# %% [markdown]
# ## Karate Club

# %%
G1 = nx.read_gml('../data/karate.gml')

# %%
cc = nx.clustering(G1)
degree = G1.degree()
bc = nx.betweenness_centrality(G1)
nx.set_node_attributes(G1,'clustering_coefficient',cc)
nx.set_node_attributes(G1,'degree',degree)
nx.set_node_attributes(G1,'betweenness_centrality',bc)

# %%
nx.draw(G1)

# %%
nodes = G1.nodes()
edges = G1.edges()

# %%
node_to_color = visJS2jupyter.visJS_module.return_node_to_color(G1,field_to_map='betweenness_centrality',cmap=mpl.cm.spring_r,alpha = 1,
                                                 color_max_frac = .9,color_min_frac = .1)

# set node initial positions using networkx's spring_layout function
pos = nx.spring_layout(G1)

nodes_dict = [{"id":n,"color":node_to_color[n],
               "degree":nx.degree(G1,n),
              "x":pos[n][0]*1000,
              "y":pos[n][1]*1000} for n in nodes
              ]
node_map = dict(zip(nodes,range(len(nodes))))  # map to indices for source/target in edges
edges_dict = [{"source":node_map[edges[i][0]], "target":node_map[edges[i][1]], 
              "color":"gray","title":'test'} for i in range(len(edges))]

# set some network-wide styles
visJS2jupyter.visJS_module.visjs_network(nodes_dict,edges_dict,
                          node_size_multiplier=7,
                          node_size_transform = '',
                          node_color_highlight_border='red',
                          node_color_highlight_background='#D3918B',
                          node_color_hover_border='blue',
                          node_color_hover_background='#8BADD3',
                          node_font_size=25,
                          edge_arrow_to=True,
                          physics_enabled=True,
                          edge_color_highlight='#8A324E',
                          edge_color_hover='#8BADD3',
                          edge_width=3,
                          max_velocity=15,
                          min_velocity=1)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file0"];    frame.runVis([{"node_shape": "dot", "degree": 16, "title": 1, "color": "rgba(256, 25, 230, 1)", "y": 517.30433342381366, "x": 241.90871092865945, "border_width": 0, "id": 1}, {"node_shape": "dot", "degree": 9, "title": 2, "color": "rgba(256, 205, 50, 1)", "y": 366.00433793572165, "x": 251.44996444074204, "border_width": 0, "id": 2}, {"node_shape": "dot", "degree": 10, "title": 3, "color": "rgba(256, 163, 92, 1)", "y": 272.99740290385364, "x": 439.03663368476316, "border_width": 0, "id": 3}, {"node_shape": "dot", "degree": 6, "title": 4, "color": "rgba(256, 224, 31, 1)", "y": 380.18714569123603, "x": 141.22838315682986, "border_width": 0, "id": 4}, {"node_shape": "dot", "degree": 3, "title": 5, "color": "rgba(256, 230, 25, 1)", "y": 643.02239799957329, "x": 29.98310753925637, "border_width": 0, "id": 5}, {"node_shape": "dot", "degree": 4, "title": 6, "color": "rgba(256, 216, 39, 1)", "y": 915.17422374670457, "x": 309.92696288517209, "border_width": 0, "id": 6}, {"node_shape": "dot", "degree": 4, "title": 7, "color": "rgba(256, 216, 39, 1)", "y": 792.70412003751994, "x": 131.79909444629058, "border_width": 0, "id": 7}, {"node_shape": "dot", "degree": 4, "title": 8, "color": "rgba(256, 230, 25, 1)", "y": 195.38721753228481, "x": 164.96532972319085, "border_width": 0, "id": 8}, {"node_shape": "dot", "degree": 5, "title": 9, "color": "rgba(256, 204, 51, 1)", "y": 535.36850613235958, "x": 564.75599214950785, "border_width": 0, "id": 9}, {"node_shape": "dot", "degree": 2, "title": 10, "color": "rgba(256, 230, 25, 1)", "y": 31.486296944765421, "x": 490.72019819999952, "border_width": 0, "id": 10}, {"node_shape": "dot", "degree": 3, "title": 11, "color": "rgba(256, 230, 25, 1)", "y": 803.15986551575975, "x": 198.18225848934296, "border_width": 0, "id": 11}, {"node_shape": "dot", "degree": 1, "title": 12, "color": "rgba(256, 230, 25, 1)", "y": 393.05260700704378, "x": 0.0, "border_width": 0, "id": 12}, {"node_shape": "dot", "degree": 2, "title": 13, "color": "rgba(256, 230, 25, 1)", "y": 685.92839617468951, "x": 56.16206355538138, "border_width": 0, "id": 13}, {"node_shape": "dot", "degree": 5, "title": 14, "color": "rgba(256, 208, 47, 1)", "y": 379.14246454011334, "x": 374.45449462251315, "border_width": 0, "id": 14}, {"node_shape": "dot", "degree": 2, "title": 15, "color": "rgba(256, 230, 25, 1)", "y": 556.37134846551987, "x": 988.86559098812393, "border_width": 0, "id": 15}, {"node_shape": "dot", "degree": 2, "title": 16, "color": "rgba(256, 230, 25, 1)", "y": 690.08506751887251, "x": 866.26161625680868, "border_width": 0, "id": 16}, {"node_shape": "dot", "degree": 2, "title": 17, "color": "rgba(256, 230, 25, 1)", "y": 892.96271683646796, "x": 250.21741423612471, "border_width": 0, "id": 17}, {"node_shape": "dot", "degree": 2, "title": 18, "color": "rgba(256, 230, 25, 1)", "y": 495.00268749710483, "x": 21.091285847403999, "border_width": 0, "id": 18}, {"node_shape": "dot", "degree": 2, "title": 19, "color": "rgba(256, 230, 25, 1)", "y": 365.57747276025316, "x": 986.25857361535043, "border_width": 0, "id": 19}, {"node_shape": "dot", "degree": 3, "title": 20, "color": "rgba(256, 215, 40, 1)", "y": 590.21181382772465, "x": 431.42669969980648, "border_width": 0, "id": 20}, {"node_shape": "dot", "degree": 2, "title": 21, "color": "rgba(256, 230, 25, 1)", "y": 462.17817002905883, "x": 1000.0, "border_width": 0, "id": 21}, {"node_shape": "dot", "degree": 2, "title": 22, "color": "rgba(256, 230, 25, 1)", "y": 261.89383675354918, "x": 46.203431563312144, "border_width": 0, "id": 22}, {"node_shape": "dot", "degree": 2, "title": 23, "color": "rgba(256, 230, 25, 1)", "y": 212.0110137602006, "x": 922.51365112046767, "border_width": 0, "id": 23}, {"node_shape": "dot", "degree": 5, "title": 24, "color": "rgba(256, 222, 33, 1)", "y": 293.81781182093675, "x": 917.00479675 ...

# %%
G2 = nx.read_gml('../data/polblogs.gml')

# %%
nx.draw(G2)

# %%
set(nx.get_node_attributes(G2,'value').values())
# Out:
# {0, 1}

# %%
nodes = G2.nodes()
edges = G2.edges()

# %%
##cc = nx.clustering(G2)
degree = G2.degree()
bc = nx.betweenness_centrality(G2)
##nx.set_node_attributes(G2,'clustering_coefficient',cc)
nx.set_node_attributes(G2,'degree',degree)
nx.set_node_attributes(G2,'betweenness_centrality',bc)

# %%
node_to_color = visJS2jupyter.visJS_module.return_node_to_color(G2,field_to_map='value',cmap=mpl.cm.spring_r,alpha = 1,
                                                 color_max_frac = .9,color_min_frac = .1)

# set node initial positions using networkx's spring_layout function
pos = nx.spring_layout(G2)

nodes_dict = [{"id":n,"color":node_to_color[n],
               "degree":nx.degree(G2,n),
              "x":pos[n][0]*1000,
              "y":pos[n][1]*1000} for n in nodes
              ]
node_map = dict(zip(nodes,range(len(nodes))))  # map to indices for source/target in edges
edges_dict = [{"source":node_map[edges[i][0]], "target":node_map[edges[i][1]], 
              "color":"gray","title":'test'} for i in range(len(edges))]

# set some network-wide styles
visJS2jupyter.visJS_module.visjs_network(nodes_dict,edges_dict,
                          node_size_multiplier=7,
                          node_size_transform = '',
                          node_color_highlight_border='red',
                          node_color_highlight_background='#D3918B',
                          node_color_hover_border='blue',
                          node_color_hover_background='#8BADD3',
                          node_font_size=25,
                          edge_arrow_to=True,
                          physics_enabled=True,
                          edge_color_highlight='#8A324E',
                          edge_color_hover='#8BADD3',
                          edge_width=3,
                          max_velocity=15,
                          min_velocity=1)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file0"];    frame.runVis([{"node_shape": "dot", "degree": 27, "title": 1, "color": "rgba(256, 230, 25, 1)", "y": 458.20325613021851, "x": 617.92927980422974, "border_width": 0, "id": 1}, {"node_shape": "dot", "degree": 48, "title": 2, "color": "rgba(256, 230, 25, 1)", "y": 370.51728367805481, "x": 501.49810314178467, "border_width": 0, "id": 2}, {"node_shape": "dot", "degree": 0, "title": 3, "color": "rgba(256, 230, 25, 1)", "y": 913.09839487075806, "x": 221.50027751922607, "border_width": 0, "id": 3}, {"node_shape": "dot", "degree": 0, "title": 4, "color": "rgba(256, 230, 25, 1)", "y": 153.37543189525604, "x": 858.94346237182617, "border_width": 0, "id": 4}, {"node_shape": "dot", "degree": 4, "title": 5, "color": "rgba(256, 230, 25, 1)", "y": 236.77973449230194, "x": 369.00502443313599, "border_width": 0, "id": 5}, {"node_shape": "dot", "degree": 1, "title": 6, "color": "rgba(256, 230, 25, 1)", "y": 425.38854479789734, "x": 773.77057075500488, "border_width": 0, "id": 6}, {"node_shape": "dot", "degree": 1, "title": 7, "color": "rgba(256, 230, 25, 1)", "y": 285.82668304443359, "x": 950.72102546691895, "border_width": 0, "id": 7}, {"node_shape": "dot", "degree": 38, "title": 8, "color": "rgba(256, 230, 25, 1)", "y": 380.54347038269043, "x": 486.54487729072571, "border_width": 0, "id": 8}, {"node_shape": "dot", "degree": 8, "title": 9, "color": "rgba(256, 230, 25, 1)", "y": 475.18104314804077, "x": 521.1188793182373, "border_width": 0, "id": 9}, {"node_shape": "dot", "degree": 15, "title": 10, "color": "rgba(256, 230, 25, 1)", "y": 366.7370080947876, "x": 570.69355249404907, "border_width": 0, "id": 10}, {"node_shape": "dot", "degree": 1, "title": 11, "color": "rgba(256, 230, 25, 1)", "y": 591.28689765930176, "x": 223.31608831882477, "border_width": 0, "id": 11}, {"node_shape": "dot", "degree": 4, "title": 12, "color": "rgba(256, 230, 25, 1)", "y": 280.30750155448914, "x": 252.06062197685242, "border_width": 0, "id": 12}, {"node_shape": "dot", "degree": 63, "title": 13, "color": "rgba(256, 230, 25, 1)", "y": 335.28029918670654, "x": 543.39492321014404, "border_width": 0, "id": 13}, {"node_shape": "dot", "degree": 89, "title": 14, "color": "rgba(256, 230, 25, 1)", "y": 445.24088501930237, "x": 584.88214015960693, "border_width": 0, "id": 14}, {"node_shape": "dot", "degree": 70, "title": 15, "color": "rgba(256, 230, 25, 1)", "y": 385.95569133758545, "x": 544.62623596191406, "border_width": 0, "id": 15}, {"node_shape": "dot", "degree": 54, "title": 16, "color": "rgba(256, 230, 25, 1)", "y": 401.53911709785461, "x": 561.47927045822144, "border_width": 0, "id": 16}, {"node_shape": "dot", "degree": 2, "title": 17, "color": "rgba(256, 230, 25, 1)", "y": 492.07374453544617, "x": 818.94558668136597, "border_width": 0, "id": 17}, {"node_shape": "dot", "degree": 48, "title": 18, "color": "rgba(256, 230, 25, 1)", "y": 360.74426770210266, "x": 515.84553718566895, "border_width": 0, "id": 18}, {"node_shape": "dot", "degree": 4, "title": 19, "color": "rgba(256, 230, 25, 1)", "y": 293.64544153213501, "x": 801.97107791900635, "border_width": 0, "id": 19}, {"node_shape": "dot", "degree": 13, "title": 20, "color": "rgba(256, 230, 25, 1)", "y": 317.54264235496521, "x": 498.02905321121216, "border_width": 0, "id": 20}, {"node_shape": "dot", "degree": 48, "title": 21, "color": "rgba(256, 230, 25, 1)", "y": 447.77384400367737, "x": 464.63918685913086, "border_width": 0, "id": 21}, {"node_shape": "dot", "degree": 26, "title": 22, "color": "rgba(256, 230, 25, 1)", "y": 509.95296239852905, "x": 533.79291296005249, "border_width": 0, "id": 22}, {"node_shape": "dot", "degree": 98, "title": 23, "color": "rgba(256, 230, 25, 1)", "y": 429.14101481437683, "x": 576.54827833175659, "border_width": 0, "id": 23}, {"node_shape": "dot", "degree": 81, "title": 24, "color": "rgba(256, 230, 25, 1)", "y ...
