# %% [markdown]
# # Import Libraries

# %%
import matplotlib as mpl
import networkx as nx
import visJS2jupyter.visJS_module
# %matplotlib inline

# %%
G = nx.read_gml('../data/dolphins.gml')

# %%
nodes = G.nodes()
edges = G.edges()

# %% [markdown]
# ## Add a node attributes to color-code by

# %%
cc = nx.clustering(G)
degree = G.degree()
bc = nx.betweenness_centrality(G)
nx.set_node_attributes(G,'clustering_coefficient',cc)
nx.set_node_attributes(G,'degree',degree)
nx.set_node_attributes(G,'betweenness_centrality',bc)

# %% [markdown]
# ## Dolphins

# %%
nx.draw(G)

# %% [markdown]
# ### Map the betweenness centrality to the node color, using matplotlib spring_r colormap

# %% [markdown]
# ## Dolphins

# %%
node_to_color = visJS2jupyter.visJS_module.return_node_to_color(G,field_to_map='betweenness_centrality',cmap=mpl.cm.spring_r,alpha = 1,
                                                 color_max_frac = .9,color_min_frac = .1)

# set node initial positions using networkx's spring_layout function
pos = nx.spring_layout(G)

node_labels = nx.get_node_attributes(G,'label')

nodes_dict = [{"id":n,"color":node_to_color[n],
               "degree":nx.degree(G,n),
               "node_label":node_labels[n],
              "x":pos[n][0]*1000,
              "y":pos[n][1]*1000} for n in nodes
              ]
node_map = dict(zip(nodes,range(len(nodes))))  # map to indices for source/target in edges
edges_dict = [{"source":node_map[edges[i][0]], "target":node_map[edges[i][1]], 
              "color":"gray","title":'test'} for i in range(len(edges))]

# set some network-wide styles
visJS2jupyter.visJS_module.visjs_network(nodes_dict,edges_dict,
                          node_size_multiplier=7,
                          node_size_transform = '',
                          node_color_highlight_border='red',
                          node_color_highlight_background='#D3918B',
                          node_color_hover_border='blue',
                          node_color_hover_background='#8BADD3',
                          node_font_size=25,
                          node_label_field='node_label',               
                          edge_arrow_to=True,
                          physics_enabled=True,
                          edge_color_highlight='#8A324E',
                          edge_color_hover='#8BADD3',
                          edge_width=3,
                          max_velocity=15,
                          min_velocity=1,
                          graph_id="0")
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file0"];    frame.runVis([{"node_label": "Beak", "node_shape": "dot", "degree": 6, "title": 0, "color": "rgba(256, 214, 41, 1)", "y": 446.73637209421736, "x": 840.81368547107991, "border_width": 0, "id": 0}, {"node_label": "Beescratch", "node_shape": "dot", "degree": 8, "title": 1, "color": "rgba(256, 54, 201, 1)", "y": 138.66289111583347, "x": 437.61907511025231, "border_width": 0, "id": 1}, {"node_label": "Bumper", "node_shape": "dot", "degree": 4, "title": 2, "color": "rgba(256, 222, 33, 1)", "y": 784.30358367447775, "x": 896.4585739759799, "border_width": 0, "id": 2}, {"node_label": "CCL", "node_shape": "dot", "degree": 3, "title": 3, "color": "rgba(256, 228, 27, 1)", "y": 336.83079503244613, "x": 845.79627771731418, "border_width": 0, "id": 3}, {"node_label": "Cross", "node_shape": "dot", "degree": 1, "title": 4, "color": "rgba(256, 230, 25, 1)", "y": 699.58363017306863, "x": 167.01187578433914, "border_width": 0, "id": 4}, {"node_label": "DN16", "node_shape": "dot", "degree": 4, "title": 5, "color": "rgba(256, 226, 29, 1)", "y": 435.32505441884217, "x": 0.0, "border_width": 0, "id": 5}, {"node_label": "DN21", "node_shape": "dot", "degree": 6, "title": 6, "color": "rgba(256, 206, 49, 1)", "y": 335.24373201085149, "x": 52.799710238065387, "border_width": 0, "id": 6}, {"node_label": "DN63", "node_shape": "dot", "degree": 5, "title": 7, "color": "rgba(256, 132, 123, 1)", "y": 121.17168838825674, "x": 586.2544685009118, "border_width": 0, "id": 7}, {"node_label": "Double", "node_shape": "dot", "degree": 6, "title": 8, "color": "rgba(256, 211, 44, 1)", "y": 408.21716580906701, "x": 720.05377593747744, "border_width": 0, "id": 8}, {"node_label": "Feather", "node_shape": "dot", "degree": 7, "title": 9, "color": "rgba(256, 213, 42, 1)", "y": 268.96028658591206, "x": 56.765094526817663, "border_width": 0, "id": 9}, {"node_label": "Fish", "node_shape": "dot", "degree": 5, "title": 10, "color": "rgba(256, 217, 38, 1)", "y": 532.8227331447107, "x": 951.80184646003056, "border_width": 0, "id": 10}, {"node_label": "Five", "node_shape": "dot", "degree": 1, "title": 11, "color": "rgba(256, 230, 25, 1)", "y": 660.80634370884127, "x": 221.060233716102, "border_width": 0, "id": 11}, {"node_label": "Fork", "node_shape": "dot", "degree": 1, "title": 12, "color": "rgba(256, 230, 25, 1)", "y": 488.80626006942833, "x": 1000.0, "border_width": 0, "id": 12}, {"node_label": "Gallatin", "node_shape": "dot", "degree": 8, "title": 13, "color": "rgba(256, 186, 69, 1)", "y": 223.90833074188728, "x": 84.781351587198927, "border_width": 0, "id": 13}, {"node_label": "Grin", "node_shape": "dot", "degree": 12, "title": 14, "color": "rgba(256, 179, 76, 1)", "y": 653.46374803179458, "x": 796.06771737607335, "border_width": 0, "id": 14}, {"node_label": "Haecksel", "node_shape": "dot", "degree": 7, "title": 15, "color": "rgba(256, 202, 53, 1)", "y": 587.71953592726686, "x": 531.30338050300861, "border_width": 0, "id": 15}, {"node_label": "Hook", "node_shape": "dot", "degree": 6, "title": 16, "color": "rgba(256, 227, 28, 1)", "y": 786.09192759965129, "x": 827.41015301795119, "border_width": 0, "id": 16}, {"node_label": "Jet", "node_shape": "dot", "degree": 9, "title": 17, "color": "rgba(256, 136, 119, 1)", "y": 206.5510339452569, "x": 193.4400678985273, "border_width": 0, "id": 17}, {"node_label": "Jonah", "node_shape": "dot", "degree": 7, "title": 18, "color": "rgba(256, 218, 37, 1)", "y": 721.52756113217561, "x": 578.61677785002394, "border_width": 0, "id": 18}, {"node_label": "Knit", "node_shape": "dot", "degree": 4, "title": 19, "color": "rgba(256, 219, 36, 1)", "y": 3.4700870802993409, "x": 519.41754197782211, "border_width": 0, "id": 19}, {"node_label": "Kringel", "node_shape": "dot", "degree": 9, "title": 20, "color": "rgba(256, 145, 110, 1)", "y": 526.06109323645057, "x": 787.035200267672 ...

# %% [markdown]
# ## Karate Club

# %%
G1 = nx.read_gml('../data/karate.gml')

# %%
cc = nx.clustering(G1)
degree = G1.degree()
bc = nx.betweenness_centrality(G1)
nx.set_node_attributes(G1,'clustering_coefficient',cc)
nx.set_node_attributes(G1,'degree',degree)
nx.set_node_attributes(G1,'betweenness_centrality',bc)

# %%
nodes = G1.nodes()
edges = G1.edges()

# %%
node_to_color = visJS2jupyter.visJS_module.return_node_to_color(G1,field_to_map='betweenness_centrality',cmap=mpl.cm.spring_r,alpha = 1,
                                                 color_max_frac = .9,color_min_frac = .1)

# set node initial positions using networkx's spring_layout function
pos = nx.spring_layout(G1)

nodes_dict = [{"id":n,"color":node_to_color[n],
               "degree":nx.degree(G1,n),
              "x":pos[n][0]*1000,
              "y":pos[n][1]*1000} for n in nodes
              ]
node_map = dict(zip(nodes,range(len(nodes))))  # map to indices for source/target in edges
edges_dict = [{"source":node_map[edges[i][0]], "target":node_map[edges[i][1]], 
              "color":"gray","title":'test'} for i in range(len(edges))]

# set some network-wide styles
visJS2jupyter.visJS_module.visjs_network(nodes_dict,edges_dict,
                          node_size_multiplier=7,
                          node_size_transform = '',
                          node_color_highlight_border='red',
                          node_color_highlight_background='#D3918B',
                          node_color_hover_border='blue',
                          node_color_hover_background='#8BADD3',
                          node_font_size=25,
                          edge_arrow_to=False,
                          physics_enabled=True,
                          edge_color_highlight='#8A324E',
                          edge_color_hover='#8BADD3',
                          edge_width=3,
                          max_velocity=15,
                          min_velocity=1,
                          graph_id="1")
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file1"];    frame.runVis([{"node_shape": "dot", "degree": 16, "title": 1, "color": "rgba(256, 25, 230, 1)", "y": 342.62596504276695, "x": 719.35007981856347, "border_width": 0, "id": 1}, {"node_shape": "dot", "degree": 9, "title": 2, "color": "rgba(256, 205, 50, 1)", "y": 424.56776457885246, "x": 769.66690245727898, "border_width": 0, "id": 2}, {"node_shape": "dot", "degree": 10, "title": 3, "color": "rgba(256, 163, 92, 1)", "y": 677.46757985110844, "x": 654.70493800458826, "border_width": 0, "id": 3}, {"node_shape": "dot", "degree": 6, "title": 4, "color": "rgba(256, 224, 31, 1)", "y": 529.30643288116801, "x": 896.10326211444578, "border_width": 0, "id": 4}, {"node_shape": "dot", "degree": 3, "title": 5, "color": "rgba(256, 230, 25, 1)", "y": 72.510561218017685, "x": 745.42363750337881, "border_width": 0, "id": 5}, {"node_shape": "dot", "degree": 4, "title": 6, "color": "rgba(256, 216, 39, 1)", "y": 0.0, "x": 497.08139884321321, "border_width": 0, "id": 6}, {"node_shape": "dot", "degree": 4, "title": 7, "color": "rgba(256, 216, 39, 1)", "y": 29.261794247324886, "x": 570.47054779489895, "border_width": 0, "id": 7}, {"node_shape": "dot", "degree": 4, "title": 8, "color": "rgba(256, 230, 25, 1)", "y": 626.30504644329505, "x": 921.79789202453583, "border_width": 0, "id": 8}, {"node_shape": "dot", "degree": 5, "title": 9, "color": "rgba(256, 204, 51, 1)", "y": 536.68579074383808, "x": 500.05038618935447, "border_width": 0, "id": 9}, {"node_shape": "dot", "degree": 2, "title": 10, "color": "rgba(256, 230, 25, 1)", "y": 924.39406457754205, "x": 678.24986997938629, "border_width": 0, "id": 10}, {"node_shape": "dot", "degree": 3, "title": 11, "color": "rgba(256, 230, 25, 1)", "y": 26.010215221164199, "x": 665.53888458821768, "border_width": 0, "id": 11}, {"node_shape": "dot", "degree": 1, "title": 12, "color": "rgba(256, 230, 25, 1)", "y": 478.57798841852252, "x": 1000.0, "border_width": 0, "id": 12}, {"node_shape": "dot", "degree": 2, "title": 13, "color": "rgba(256, 230, 25, 1)", "y": 362.98693577798616, "x": 988.65748219686714, "border_width": 0, "id": 13}, {"node_shape": "dot", "degree": 5, "title": 14, "color": "rgba(256, 208, 47, 1)", "y": 571.10990438636827, "x": 705.00935085901006, "border_width": 0, "id": 14}, {"node_shape": "dot", "degree": 2, "title": 15, "color": "rgba(256, 230, 25, 1)", "y": 519.0044865451415, "x": 58.758719858483516, "border_width": 0, "id": 15}, {"node_shape": "dot", "degree": 2, "title": 16, "color": "rgba(256, 230, 25, 1)", "y": 955.35290251187973, "x": 406.57857892128993, "border_width": 0, "id": 16}, {"node_shape": "dot", "degree": 2, "title": 17, "color": "rgba(256, 230, 25, 1)", "y": 10.219730886271142, "x": 339.7965238713719, "border_width": 0, "id": 17}, {"node_shape": "dot", "degree": 2, "title": 18, "color": "rgba(256, 230, 25, 1)", "y": 166.0961663394998, "x": 872.27879345393978, "border_width": 0, "id": 18}, {"node_shape": "dot", "degree": 2, "title": 19, "color": "rgba(256, 230, 25, 1)", "y": 935.26499929139015, "x": 304.16343198553255, "border_width": 0, "id": 19}, {"node_shape": "dot", "degree": 3, "title": 20, "color": "rgba(256, 215, 40, 1)", "y": 350.50277305994325, "x": 531.73808909577917, "border_width": 0, "id": 20}, {"node_shape": "dot", "degree": 2, "title": 21, "color": "rgba(256, 230, 25, 1)", "y": 695.32361234770917, "x": 48.336493124673957, "border_width": 0, "id": 21}, {"node_shape": "dot", "degree": 2, "title": 22, "color": "rgba(256, 230, 25, 1)", "y": 250.02797005224497, "x": 940.32369801616949, "border_width": 0, "id": 22}, {"node_shape": "dot", "degree": 2, "title": 23, "color": "rgba(256, 230, 25, 1)", "y": 401.00170257004572, "x": 120.18484010788802, "border_width": 0, "id": 23}, {"node_shape": "dot", "degree": 5, "title": 24, "color": "rgba(256, 222, 33, 1)", "y": 779.34704542177303, "x": 116.01318908 ...

# %% [markdown]
# ## Political Blogs

# %%
G2 = nx.read_gml('../data/polblogs.gml')

# %%
nodes = G2.nodes()
edges = G2.edges()

# %%
degree = G2.degree()
bc = nx.betweenness_centrality(G2)
nx.set_node_attributes(G2,'degree',degree)
nx.set_node_attributes(G2,'betweenness_centrality',bc)

# %%
node_to_color = visJS2jupyter.visJS_module.return_node_to_color(G2,field_to_map='value',cmap=mpl.cm.spring_r,alpha = 1,
                                                 color_max_frac = .9,color_min_frac = .1)

# set node initial positions using networkx's spring_layout function
pos = nx.spring_layout(G2)

nodes_dict = [{"id":n,
               "color":node_to_color[n],
               "degree":nx.degree(G2,n),
              "x":pos[n][0]*1000,
              "y":pos[n][1]*1000} for n in nodes
              ]
node_map = dict(zip(nodes,range(len(nodes))))  # map to indices for source/target in edges
edges_dict = [{"source":node_map[edges[i][0]], "target":node_map[edges[i][1]], 
              "color":"gray","title":'test'} for i in range(len(edges))]

# set some network-wide styles
visJS2jupyter.visJS_module.visjs_network(nodes_dict,edges_dict,
                          node_size_multiplier=2,
                          node_size_transform = '',
                          node_color_highlight_border='red',
                          node_color_highlight_background='#D3918B',
                          node_color_hover_border='blue',
                          node_color_hover_background='#8BADD3',
                          node_font_size=25,
                          edge_arrow_to=True,
                          physics_enabled=True,
                          edge_color_highlight='#8A324E',
                          edge_color_hover='#8BADD3',
                          edge_width=3,
                          max_velocity=15,
                          min_velocity=1,
                          graph_id="2")
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file2"];    frame.runVis([{"node_shape": "dot", "degree": 27, "title": 1, "color": "rgba(256, 230, 25, 1)", "y": 447.28127121925354, "x": 593.93566846847534, "border_width": 0, "id": 1}, {"node_shape": "dot", "degree": 48, "title": 2, "color": "rgba(256, 230, 25, 1)", "y": 608.83134603500366, "x": 539.05755281448364, "border_width": 0, "id": 2}, {"node_shape": "dot", "degree": 0, "title": 3, "color": "rgba(256, 230, 25, 1)", "y": 800.05884170532227, "x": 899.14482831954956, "border_width": 0, "id": 3}, {"node_shape": "dot", "degree": 0, "title": 4, "color": "rgba(256, 230, 25, 1)", "y": 265.49297571182251, "x": 939.93687629699707, "border_width": 0, "id": 4}, {"node_shape": "dot", "degree": 4, "title": 5, "color": "rgba(256, 230, 25, 1)", "y": 428.60230803489685, "x": 716.70442819595337, "border_width": 0, "id": 5}, {"node_shape": "dot", "degree": 1, "title": 6, "color": "rgba(256, 230, 25, 1)", "y": 694.35834884643555, "x": 807.1744441986084, "border_width": 0, "id": 6}, {"node_shape": "dot", "degree": 1, "title": 7, "color": "rgba(256, 230, 25, 1)", "y": 707.10206031799316, "x": 45.996304601430893, "border_width": 0, "id": 7}, {"node_shape": "dot", "degree": 38, "title": 8, "color": "rgba(256, 230, 25, 1)", "y": 563.84587287902832, "x": 625.27632713317871, "border_width": 0, "id": 8}, {"node_shape": "dot", "degree": 8, "title": 9, "color": "rgba(256, 230, 25, 1)", "y": 388.47276568412781, "x": 398.26342463493347, "border_width": 0, "id": 9}, {"node_shape": "dot", "degree": 15, "title": 10, "color": "rgba(256, 230, 25, 1)", "y": 593.45608949661255, "x": 525.80857276916504, "border_width": 0, "id": 10}, {"node_shape": "dot", "degree": 1, "title": 11, "color": "rgba(256, 230, 25, 1)", "y": 133.24446976184845, "x": 638.41670751571655, "border_width": 0, "id": 11}, {"node_shape": "dot", "degree": 4, "title": 12, "color": "rgba(256, 230, 25, 1)", "y": 566.12986326217651, "x": 356.08416795730591, "border_width": 0, "id": 12}, {"node_shape": "dot", "degree": 63, "title": 13, "color": "rgba(256, 230, 25, 1)", "y": 598.10924530029297, "x": 521.14295959472656, "border_width": 0, "id": 13}, {"node_shape": "dot", "degree": 89, "title": 14, "color": "rgba(256, 230, 25, 1)", "y": 502.40260362625122, "x": 546.94700241088867, "border_width": 0, "id": 14}, {"node_shape": "dot", "degree": 70, "title": 15, "color": "rgba(256, 230, 25, 1)", "y": 611.08988523483276, "x": 598.63144159317017, "border_width": 0, "id": 15}, {"node_shape": "dot", "degree": 54, "title": 16, "color": "rgba(256, 230, 25, 1)", "y": 522.98301458358765, "x": 578.67681980133057, "border_width": 0, "id": 16}, {"node_shape": "dot", "degree": 2, "title": 17, "color": "rgba(256, 230, 25, 1)", "y": 386.24799251556396, "x": 791.39441251754761, "border_width": 0, "id": 17}, {"node_shape": "dot", "degree": 48, "title": 18, "color": "rgba(256, 230, 25, 1)", "y": 579.80203628540039, "x": 579.80746030807495, "border_width": 0, "id": 18}, {"node_shape": "dot", "degree": 4, "title": 19, "color": "rgba(256, 230, 25, 1)", "y": 741.48303270339966, "x": 758.77952575683594, "border_width": 0, "id": 19}, {"node_shape": "dot", "degree": 13, "title": 20, "color": "rgba(256, 230, 25, 1)", "y": 633.27294588088989, "x": 624.22287464141846, "border_width": 0, "id": 20}, {"node_shape": "dot", "degree": 48, "title": 21, "color": "rgba(256, 230, 25, 1)", "y": 439.09037113189697, "x": 518.53281259536743, "border_width": 0, "id": 21}, {"node_shape": "dot", "degree": 26, "title": 22, "color": "rgba(256, 230, 25, 1)", "y": 456.07262849807739, "x": 626.8267035484314, "border_width": 0, "id": 22}, {"node_shape": "dot", "degree": 98, "title": 23, "color": "rgba(256, 230, 25, 1)", "y": 514.21928405761719, "x": 637.137770652771, "border_width": 0, "id": 23}, {"node_shape": "dot", "degree": 81, "title": 24, "color": "rgba(256, 230, 25, 1)", "y": ...

# %% [markdown]
# ## Alternative graphing packages and representations
# * other packages
# * heatmap
