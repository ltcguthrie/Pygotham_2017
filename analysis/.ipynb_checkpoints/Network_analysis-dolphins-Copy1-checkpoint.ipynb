# %% [markdown]
# # Import Libraries

# %%
import matplotlib as mpl
import networkx as nx
import visJS2jupyter.visJS_module
# %matplotlib inline

G = nx.read_gml('../data/dolphins.gml')

nodes = G.nodes()
edges = G.edges()

## Add a node attributes to color-code by

cc = nx.clustering(G)
degree = G.degree()
bc = nx.betweenness_centrality(G)
nx.set_node_attributes(G,'clustering_coefficient',cc)
nx.set_node_attributes(G,'degree',degree)
nx.set_node_attributes(G,'betweenness_centrality',bc)



### Map the betweenness centrality to the node color, using matplotlib spring_r colormap

node_to_color = visJS2jupyter.visJS_module.return_node_to_color(G,field_to_map='betweenness_centrality',cmap=mpl.cm.spring_r,alpha = 1,
                                                 color_max_frac = .9,color_min_frac = .1)

# set node initial positions using networkx's spring_layout function
pos = nx.spring_layout(G)

node_labels = nx.get_node_attributes(G,'label')

nodes_dict = [{"id":n,"color":node_to_color[n],
               "degree":nx.degree(G,n),
               "node_label":node_labels[n],
              "x":pos[n][0]*1000,
              "y":pos[n][1]*1000} for n in nodes
              ]
node_map = dict(zip(nodes,range(len(nodes))))  # map to indices for source/target in edges
edges_dict = [{"source":node_map[edges[i][0]], "target":node_map[edges[i][1]], 
              "color":"gray","title":'test'} for i in range(len(edges))]

# set some network-wide styles
visJS2jupyter.visJS_module.visjs_network(nodes_dict,edges_dict,
                          node_size_multiplier=7,
                          node_size_transform = '',
                          node_color_highlight_border='red',
                          node_color_highlight_background='#D3918B',
                          node_color_hover_border='blue',
                          node_color_hover_background='#8BADD3',
                          node_font_size=25,
                          node_label_field='node_label',               
                          edge_arrow_to=True,
                          physics_enabled=True,
                          edge_color_highlight='#8A324E',
                          edge_color_hover='#8BADD3',
                          edge_width=3,
                          max_velocity=15,
                          min_velocity=1,
                          graph_id="0",
                          export_network=True,
                          export_file = 'dolphin_network.json')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-de246032389e> in <module>()
#      59                           graph_id="0",
#      60                           export_network=True,
# ---> 61                           export_file = 'dolphin_network.json')
#
# /Users/leahguthrie/anaconda2/lib/python2.7/site-packages/visJS2jupyter/visJS_module.pyc in visjs_network(nodes_dict, edges_dict, node_border_width, node_border_width_selected, node_broken_image, node_color_border, node_color_highlight_border, node_color_highlight_background, node_color_hover_border, node_color_hover_background, node_fixed_x, node_fixed_y, node_font_color, node_font_size, node_font_face, node_font_background, node_font_stroke_width, node_font_stroke_color, node_font_align, node_icon_face, node_icon_code, node_icon_size, node_icon_color, node_image, node_label_highlight_bold, node_scaling_min, node_scaling_max, node_scaling_label_enabled, node_scaling_label_min, node_scaling_label_max, node_scaling_label_max_visible, node_scaling_label_draw_threshold, node_shadow_enabled, node_shadow_color, node_shadow_size, node_shadow_x, node_shadow_y, node_shape_border_dashes, node_shape_border_radius, node_shape_interpolation, node_shape_use_image_size, node_shape_use_border_with_image, node_label_field, node_size_field, node_size_transform, node_size_multiplier, edge_title_field, edge_arrow_to, edge_arrow_from, edge_arrow_middle, edge_arrow_to_scale_factor, edge_arrow_from_scale_factor, edge_arrow_middle_scale_factor, edge_arrow_strikethrough, edge_color, edge_color_highlight, edge_color_hover, edge_color_inherit, edge_color_opacity, edge_dashes, edge_font_color, edge_font_size, edge_font_face, edge_font_background, edge_font_strokeWidth, edge_font_stroke_color, edge_font_align, edge_hoverWidth, edge_label_highlight_bold, edge_length, edge_scaling_min, edge_scaling_max, edge_scaling_label_enabled, edge_scaling_label_min, edge_scaling_label_max, edge_scaling_label_max_visible, edge_scaling_label_draw_threshold, edge_selection_width, edge_selfReferenceSize, edge_shadow_enabled, edge_shadow_color, edge_shadow_size, edge_shadow_x, edge_shadow_y, edge_smooth_enabled, edge_smooth_type, edge_smooth_force_direction, edge_smooth_roundness, edge_width, edge_label_field, drag_nodes, drag_view, hide_edges_on_drag, hide_nodes_on_drag, hover, hover_connected_edges, keyboard_enabled, keyboard_speed_x, keyboard_speed_y, keyboard_speed_zoom, keyboard_bind_to_window, multiselect, navigation_buttons, selectable, select_connected_edges, tooltip_delay, zoom_view, config_enabled, config_filter, container, showButton, border_color, physics_enabled, min_velocity, max_velocity, draw_threshold, min_label_size, max_label_size, max_visible, graph_title, graph_width, graph_height, scaling_factor, time_stamp, graph_id, export_network, export_file)
#     217
#     218     if export_network:
# --> 219         export_to_cytoscape(nodes_dict,edges_dict,export_file)
#     220
#     221     create_graph_style_file(filename = fname_temp,
#
# /Users/leahguthrie/anaconda2/lib/python2.7/site-packages/visJS2jupyter/visJS_module.pyc in export_to_cytoscape(nodes_dict, edges_dict, export_file)
#     395     nodes = [node['id'] for node in nodes_dict]
#     396     edges = [(edge['source'],edge['target']) for edge in edges_dict]
# --> 397     G = nx.Graph()
#     398     G.add_nodes_from(nodes)
#     399     G.add_edges_from(edges)
#
# NameError: global name 'nx' is not defined

# %%
## Dolphins

# %%
# ?visJS2jupyter.visJS_module.visjs_network()

# %%
nx.draw(G)

# %%
### How will the community split?

# %%
###visJS2jupyter.visJS_module.visjs_network()
# Out:
# Object `visJS_module.visjs_network` not found.
