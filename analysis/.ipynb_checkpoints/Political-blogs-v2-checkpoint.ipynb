# %%
import matplotlib as mpl
import networkx as nx
import visJS2jupyter.visJS_module
# %matplotlib inline

# %% [markdown]
# ## Political Blogs

# %%
G2 = nx.read_gml('../data/polblogs.gml')

# %%
nodes = G2.nodes()
edges = G2.edges()

# %%
degree = G2.degree()
bc = nx.betweenness_centrality(G2)
nx.set_node_attributes(G2,'degree',degree)
nx.set_node_attributes(G2,'betweenness_centrality',bc)

# %%
node_to_color = visJS2jupyter.visJS_module.return_node_to_color(G2,field_to_map='value',cmap=mpl.cm.spring_r,alpha = 1,
                                                 color_max_frac = .9,color_min_frac = .1)

# set node initial positions using networkx's spring_layout function
pos = nx.spring_layout(G2)

nodes_dict = [{"id":n,
               "color":node_to_color[n],
               #"degree":nx.degree(G2,n),
              "x":pos[n][0]*1000,
              "y":pos[n][1]*1000} for n in nodes
              ]
node_map = dict(zip(nodes,range(len(nodes))))  # map to indices for source/target in edges
edges_dict = [{"source":node_map[edges[i][0]], "target":node_map[edges[i][1]], 
              "color":"gray","title":'test'} for i in range(len(edges))]

# set some network-wide styles
visJS2jupyter.visJS_module.visjs_network(nodes_dict,edges_dict,
                          #node_size_multiplier=1,
                          node_size_transform = '',
                          node_color_highlight_border='red',
                          node_color_highlight_background='#D3918B',
                          node_color_hover_border='blue',
                          node_color_hover_background='#8BADD3',
                          node_font_size=25,
                          edge_arrow_to=False,
                          hover = True,
                          physics_enabled=False,
                          edge_color_highlight='#8A324E',
                          edge_color_hover='#8BADD3',
                          edge_width=3,
                          max_velocity=15,
                          min_velocity=1,
                          graph_id="2")
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file2"];    frame.runVis([{"node_shape": "dot", "degree": 3.0, "title": 1, "color": "rgba(256, 230, 25, 1)", "y": 420.45804858207703, "x": 609.18921232223511, "border_width": 0, "id": 1}, {"node_shape": "dot", "degree": 3.0, "title": 2, "color": "rgba(256, 230, 25, 1)", "y": 400.74843168258667, "x": 509.11128520965576, "border_width": 0, "id": 2}, {"node_shape": "dot", "degree": 3.0, "title": 3, "color": "rgba(256, 230, 25, 1)", "y": 665.21960496902466, "x": 31.611323356628418, "border_width": 0, "id": 3}, {"node_shape": "dot", "degree": 3.0, "title": 4, "color": "rgba(256, 230, 25, 1)", "y": 406.3488245010376, "x": 9.083935059607029, "border_width": 0, "id": 4}, {"node_shape": "dot", "degree": 3.0, "title": 5, "color": "rgba(256, 230, 25, 1)", "y": 347.19982743263245, "x": 305.63351511955261, "border_width": 0, "id": 5}, {"node_shape": "dot", "degree": 3.0, "title": 6, "color": "rgba(256, 230, 25, 1)", "y": 188.19953501224518, "x": 305.82195520401001, "border_width": 0, "id": 6}, {"node_shape": "dot", "degree": 3.0, "title": 7, "color": "rgba(256, 230, 25, 1)", "y": 0.27617139858193696, "x": 501.60831212997437, "border_width": 0, "id": 7}, {"node_shape": "dot", "degree": 3.0, "title": 8, "color": "rgba(256, 230, 25, 1)", "y": 344.78521347045898, "x": 526.3817310333252, "border_width": 0, "id": 8}, {"node_shape": "dot", "degree": 3.0, "title": 9, "color": "rgba(256, 230, 25, 1)", "y": 356.62096738815308, "x": 695.34134864807129, "border_width": 0, "id": 9}, {"node_shape": "dot", "degree": 3.0, "title": 10, "color": "rgba(256, 230, 25, 1)", "y": 359.46124792098999, "x": 537.77557611465454, "border_width": 0, "id": 10}, {"node_shape": "dot", "degree": 3.0, "title": 11, "color": "rgba(256, 230, 25, 1)", "y": 582.77994394302368, "x": 211.17740869522095, "border_width": 0, "id": 11}, {"node_shape": "dot", "degree": 3.0, "title": 12, "color": "rgba(256, 230, 25, 1)", "y": 431.90604448318481, "x": 752.155601978302, "border_width": 0, "id": 12}, {"node_shape": "dot", "degree": 3.0, "title": 13, "color": "rgba(256, 230, 25, 1)", "y": 361.74657940864563, "x": 594.62040662765503, "border_width": 0, "id": 13}, {"node_shape": "dot", "degree": 3.0, "title": 14, "color": "rgba(256, 230, 25, 1)", "y": 481.5429151058197, "x": 471.31255269050598, "border_width": 0, "id": 14}, {"node_shape": "dot", "degree": 3.0, "title": 15, "color": "rgba(256, 230, 25, 1)", "y": 367.59176850318909, "x": 563.98195028305054, "border_width": 0, "id": 15}, {"node_shape": "dot", "degree": 3.0, "title": 16, "color": "rgba(256, 230, 25, 1)", "y": 406.91757202148438, "x": 485.49830913543701, "border_width": 0, "id": 16}, {"node_shape": "dot", "degree": 3.0, "title": 17, "color": "rgba(256, 230, 25, 1)", "y": 376.33684277534485, "x": 191.3127601146698, "border_width": 0, "id": 17}, {"node_shape": "dot", "degree": 3.0, "title": 18, "color": "rgba(256, 230, 25, 1)", "y": 398.00730347633362, "x": 540.44258594512939, "border_width": 0, "id": 18}, {"node_shape": "dot", "degree": 3.0, "title": 19, "color": "rgba(256, 230, 25, 1)", "y": 224.16961193084717, "x": 683.65514278411865, "border_width": 0, "id": 19}, {"node_shape": "dot", "degree": 3.0, "title": 20, "color": "rgba(256, 230, 25, 1)", "y": 495.26837468147278, "x": 573.66847991943359, "border_width": 0, "id": 20}, {"node_shape": "dot", "degree": 3.0, "title": 21, "color": "rgba(256, 230, 25, 1)", "y": 350.83314776420593, "x": 494.05780434608459, "border_width": 0, "id": 21}, {"node_shape": "dot", "degree": 3.0, "title": 22, "color": "rgba(256, 230, 25, 1)", "y": 451.59730315208435, "x": 429.68830466270447, "border_width": 0, "id": 22}, {"node_shape": "dot", "degree": 3.0, "title": 23, "color": "rgba(256, 230, 25, 1)", "y": 475.18754005432129, "x": 502.11495161056519, "border_width": 0, "id": 23}, {"node_shape": "dot", "degree": 3.0, "title": 24, "color ...
