# %% [markdown]
# ## Bacteria

# %%
import matplotlib as mpl
import networkx as nx
import visJS2jupyter.visJS_module
# %matplotlib inline

B1 = nx.Graph()

B1 = nx.read_gml('../data/kr_ter.gml')

nodes = B1.nodes()
edges = B1.edges()

degree = B1.degree()
bc = nx.betweenness_centrality(B1)
nx.set_node_attributes(B1,'degree',degree)
nx.set_node_attributes(B1,'betweenness_centrality',bc)

node_to_color = visJS2jupyter.visJS_module.return_node_to_color(B1,field_to_map='betweenness_centrality',cmap=mpl.cm.spring_r,alpha = 1,
                                                 color_max_frac = .9,color_min_frac = .1)

# set node initial positions using networkx's spring_layout function
pos = nx.spring_layout(B1)

node_labels = nx.get_node_attributes(B1,'name')

nodes_dict = [{"id":n,"color":node_to_color[n],
               "degree":nx.degree(B1,n),
               #"betweenness_centrality":nx.betweenness_centrality(B1,n),
               "node_label":node_labels[n],
               "x":pos[n][0]*1000,
               "y":pos[n][1]*1000} for n in nodes]

node_map = dict(zip(nodes,range(len(nodes))))  # map to indices for source/target in edges
 

edges_dict = [{"source":node_map[edges[i][0]], "target":node_map[edges[i][1]], 
            "color":"gray","title":'test'} for i in range(len(edges))]

# set some network-wide styles
visJS2jupyter.visJS_module.visjs_network(nodes_dict,edges_dict,
                                         #,export_network = True,
                         # export_file='bact',
                          node_size_multiplier=7,
                          node_size_transform = '',
                          node_color_highlight_border='red',
                          node_color_highlight_background='#D3918B',
                          node_color_hover_border='blue',
                          node_color_hover_background='#8BADD3',
                          node_font_size=25,
                          node_label_field='node_label',               
                          edge_arrow_to=True,
                          physics_enabled=True,
                          edge_color_highlight='#8A324E',
                          edge_color_hover='#8BADD3',
                          edge_width=3,
                          max_velocity=15,
                          min_velocity=1)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file0"];    frame.runVis([{"node_label": "K01438", "node_shape": "dot", "degree": 9, "title": 0, "color": "rgba(256, 220, 35, 1)", "y": 366.63508415222168, "x": 573.57710599899292, "border_width": 0, "id": 0}, {"node_label": "K08680", "node_shape": "dot", "degree": 4, "title": 1, "color": "rgba(256, 217, 38, 1)", "y": 143.46733689308167, "x": 230.3272932767868, "border_width": 0, "id": 1}, {"node_label": "K00145", "node_shape": "dot", "degree": 4, "title": 2, "color": "rgba(256, 230, 25, 1)", "y": 187.90885806083679, "x": 389.37115669250488, "border_width": 0, "id": 2}, {"node_label": "K00019", "node_shape": "dot", "degree": 4, "title": 3, "color": "rgba(256, 230, 25, 1)", "y": 723.18345308303833, "x": 794.93570327758789, "border_width": 0, "id": 3}, {"node_label": "K01439", "node_shape": "dot", "degree": 4, "title": 4, "color": "rgba(256, 230, 25, 1)", "y": 410.10558605194092, "x": 158.29217433929443, "border_width": 0, "id": 4}, {"node_label": "K03562", "node_shape": "dot", "degree": 2, "title": 5, "color": "rgba(256, 230, 25, 1)", "y": 237.1184378862381, "x": 733.51764678955078, "border_width": 0, "id": 5}, {"node_label": "K00821", "node_shape": "dot", "degree": 8, "title": 6, "color": "rgba(256, 224, 31, 1)", "y": 290.51688313484192, "x": 327.82867550849915, "border_width": 0, "id": 6}, {"node_label": "K08350", "node_shape": "dot", "degree": 40, "title": 7, "color": "rgba(256, 229, 26, 1)", "y": 428.45034599304199, "x": 601.97979211807251, "border_width": 0, "id": 7}, {"node_label": "K08349", "node_shape": "dot", "degree": 40, "title": 8, "color": "rgba(256, 229, 26, 1)", "y": 440.75566530227661, "x": 602.86355018615723, "border_width": 0, "id": 8}, {"node_label": "K00674", "node_shape": "dot", "degree": 4, "title": 9, "color": "rgba(256, 230, 25, 1)", "y": 205.5431604385376, "x": 209.95083451271057, "border_width": 0, "id": 9}, {"node_label": "K08348", "node_shape": "dot", "degree": 40, "title": 10, "color": "rgba(256, 229, 26, 1)", "y": 423.22844266891479, "x": 605.63713312149048, "border_width": 0, "id": 10}, {"node_label": "K00127", "node_shape": "dot", "degree": 40, "title": 11, "color": "rgba(256, 229, 26, 1)", "y": 429.1667640209198, "x": 604.38358783721924, "border_width": 0, "id": 11}, {"node_label": "K00215", "node_shape": "dot", "degree": 4, "title": 12, "color": "rgba(256, 228, 27, 1)", "y": 250.5953311920166, "x": 209.2597484588623, "border_width": 0, "id": 12}, {"node_label": "K00124", "node_shape": "dot", "degree": 40, "title": 13, "color": "rgba(256, 229, 26, 1)", "y": 429.29008603096008, "x": 604.36850786209106, "border_width": 0, "id": 13}, {"node_label": "K00123", "node_shape": "dot", "degree": 40, "title": 14, "color": "rgba(256, 229, 26, 1)", "y": 427.47926712036133, "x": 604.30604219436646, "border_width": 0, "id": 14}, {"node_label": "K01000", "node_shape": "dot", "degree": 16, "title": 15, "color": "rgba(256, 182, 73, 1)", "y": 609.46249961853027, "x": 213.0766361951828, "border_width": 0, "id": 15}, {"node_label": "K01929", "node_shape": "dot", "degree": 4, "title": 16, "color": "rgba(256, 225, 30, 1)", "y": 569.59730386734009, "x": 110.29813438653946, "border_width": 0, "id": 16}, {"node_label": "K01657", "node_shape": "dot", "degree": 20, "title": 17, "color": "rgba(256, 224, 31, 1)", "y": 180.07658421993256, "x": 506.46466016769409, "border_width": 0, "id": 17}, {"node_label": "K00480", "node_shape": "dot", "degree": 10, "title": 18, "color": "rgba(256, 226, 29, 1)", "y": 158.55367481708527, "x": 569.18042898178101, "border_width": 0, "id": 18}, {"node_label": "K00799", "node_shape": "dot", "degree": 6, "title": 19, "color": "rgba(256, 229, 26, 1)", "y": 497.73037433624268, "x": 697.45635986328125, "border_width": 0, "id": 19}, {"node_label": "K05783", "node_shape": "dot", "degree": 12, "title": 20, "color": "rgba(256, 228, 27,  ...

# %%
node_to_color = visJS2jupyter.visJS_module.return_node_to_color(B1,field_to_map='betweenness_centrality',cmap=mpl.cm.spring_r,alpha = 1,
                                                 color_max_frac = .9,color_min_frac = .1)

# set node initial positions using networkx's spring_layout function
pos = nx.spring_layout(B1)

node_labels = nx.get_node_attributes(B1,'name')

nodes_dict = [{"id":n,"color":node_to_color[n],
               #"degree":nx.degree(B1,n),
               "betweenness_centrality":nx.betweenness_centrality(B1,n),
               "node_label":node_labels[n],
               "x":pos[n][0]*1000,
               "y":pos[n][1]*1000} for n in nodes]

node_map = dict(zip(nodes,range(len(nodes))))  # map to indices for source/target in edges
 

edges_dict = [{"source":node_map[edges[i][0]], "target":node_map[edges[i][1]], 
            "color":"gray","title":'test'} for i in range(len(edges))]

# set some network-wide styles
visJS2jupyter.visJS_module.visjs_network(nodes_dict,edges_dict,
                                         #,export_network = True,
                         # export_file='bact',
                          node_size_multiplier=7,
                          node_size_transform = '',
                          node_color_highlight_border='red',
                          node_color_highlight_background='#D3918B',
                          node_color_hover_border='blue',
                          node_color_hover_background='#8BADD3',
                          node_font_size=25,
                          node_label_field='node_label',               
                          edge_arrow_to=True,
                          physics_enabled=True,
                          edge_color_highlight='#8A324E',
                          edge_color_hover='#8BADD3',
                          edge_width=3,
                          max_velocity=15,
                          min_velocity=1,
                          graph_id="0")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-4-8ca7c9b26ab1> in <module>()
#      12                "node_label":node_labels[n],
#      13                "x":pos[n][0]*1000,
# ---> 14                "y":pos[n][1]*1000} for n in nodes]
#      15
#      16 node_map = dict(zip(nodes,range(len(nodes))))  # map to indices for source/target in edges
#
# /Users/leahguthrie/anaconda2/lib/python2.7/site-packages/networkx/algorithms/centrality/betweenness.pyc in betweenness_centrality(G, k, normalized, weight, endpoints, seed)
#     118                            normalized=normalized,
#     119                            directed=G.is_directed(),
# --> 120                            k=k)
#     121     return betweenness
#     122
#
# /Users/leahguthrie/anaconda2/lib/python2.7/site-packages/networkx/algorithms/centrality/betweenness.pyc in _rescale(betweenness, n, normalized, directed, k)
#     321     if scale is not None:
#     322         if k is not None:
# --> 323             scale = scale * n / k
#     324         for v in betweenness:
#     325             betweenness[v] *= scale
#
# ZeroDivisionError: float division by zero

# %%
# ?visJS2jupyter.visJS_module.visjs_network()
