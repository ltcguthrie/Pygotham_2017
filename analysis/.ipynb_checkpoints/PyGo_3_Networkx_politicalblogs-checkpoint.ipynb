# %% [markdown]
# # Import Libraries

# %%
import matplotlib as mpl
import networkx as nx
import visJS2jupyter.visJS_module
# %matplotlib inline

# %%
G2 = nx.read_gml('../data/polblogs.gml')

# %%
nx.draw(G2)

# %%
set(nx.get_node_attributes(G2,'value').values())
# Out:
# {0, 1}

# %%
nodes = G2.nodes()
edges = G2.edges()

# %%
##cc = nx.clustering(G2)
degree = G2.degree()
bc = nx.betweenness_centrality(G2)
##nx.set_node_attributes(G2,'clustering_coefficient',cc)
nx.set_node_attributes(G2,'degree',degree)
nx.set_node_attributes(G2,'betweenness_centrality',bc)

# %%
node_to_color = visJS2jupyter.visJS_module.return_node_to_color(G2,field_to_map='value',cmap=mpl.cm.spring_r,alpha = 1,
                                                 color_max_frac = .9,color_min_frac = .1)

# set node initial positions using networkx's spring_layout function
pos = nx.spring_layout(G2)

nodes_dict = [{"id":n,
               "color":node_to_color[n],
               "degree":nx.degree(G2,n),
              "x":pos[n][0]*1000,
              "y":pos[n][1]*1000} for n in nodes
              ]
node_map = dict(zip(nodes,range(len(nodes))))  # map to indices for source/target in edges
edges_dict = [{"source":node_map[edges[i][0]], "target":node_map[edges[i][1]], 
              "color":"gray","title":'test'} for i in range(len(edges))]

# set some network-wide styles
visJS2jupyter.visJS_module.visjs_network(nodes_dict,edges_dict,
                          node_size_multiplier=7,
                          node_size_transform = '',
                          node_color_highlight_border='red',
                          node_color_highlight_background='#D3918B',
                          node_color_hover_border='blue',
                          node_color_hover_background='#8BADD3',
                          node_font_size=25,
                          edge_arrow_to=True,
                          physics_enabled=True,
                          edge_color_highlight='#8A324E',
                          edge_color_hover='#8BADD3',
                          edge_width=3,
                          max_velocity=15,
                          min_velocity=1)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file0"];    frame.runVis([{"node_shape": "dot", "degree": 27, "title": 1, "color": "rgba(256, 230, 25, 1)", "y": 510.06460189819336, "x": 612.52427101135254, "border_width": 0, "id": 1}, {"node_shape": "dot", "degree": 48, "title": 2, "color": "rgba(256, 230, 25, 1)", "y": 662.75465488433838, "x": 514.01293277740479, "border_width": 0, "id": 2}, {"node_shape": "dot", "degree": 0, "title": 3, "color": "rgba(256, 230, 25, 1)", "y": 530.01284599304199, "x": 997.38872051239014, "border_width": 0, "id": 3}, {"node_shape": "dot", "degree": 0, "title": 4, "color": "rgba(256, 230, 25, 1)", "y": 616.85222387313843, "x": 14.152334071695805, "border_width": 0, "id": 4}, {"node_shape": "dot", "degree": 4, "title": 5, "color": "rgba(256, 230, 25, 1)", "y": 186.67934834957123, "x": 414.43952918052673, "border_width": 0, "id": 5}, {"node_shape": "dot", "degree": 1, "title": 6, "color": "rgba(256, 230, 25, 1)", "y": 452.04147696495056, "x": 753.35121154785156, "border_width": 0, "id": 6}, {"node_shape": "dot", "degree": 1, "title": 7, "color": "rgba(256, 230, 25, 1)", "y": 97.859479486942291, "x": 795.08119821548462, "border_width": 0, "id": 7}, {"node_shape": "dot", "degree": 38, "title": 8, "color": "rgba(256, 230, 25, 1)", "y": 628.71354818344116, "x": 541.89491271972656, "border_width": 0, "id": 8}, {"node_shape": "dot", "degree": 8, "title": 9, "color": "rgba(256, 230, 25, 1)", "y": 682.09415674209595, "x": 419.85580325126648, "border_width": 0, "id": 9}, {"node_shape": "dot", "degree": 15, "title": 10, "color": "rgba(256, 230, 25, 1)", "y": 667.00500249862671, "x": 575.63233375549316, "border_width": 0, "id": 10}, {"node_shape": "dot", "degree": 1, "title": 11, "color": "rgba(256, 230, 25, 1)", "y": 210.07031202316284, "x": 367.33511090278625, "border_width": 0, "id": 11}, {"node_shape": "dot", "degree": 4, "title": 12, "color": "rgba(256, 230, 25, 1)", "y": 512.97038793563843, "x": 723.15305471420288, "border_width": 0, "id": 12}, {"node_shape": "dot", "degree": 63, "title": 13, "color": "rgba(256, 230, 25, 1)", "y": 627.08258628845215, "x": 589.70719575881958, "border_width": 0, "id": 13}, {"node_shape": "dot", "degree": 89, "title": 14, "color": "rgba(256, 230, 25, 1)", "y": 561.22195720672607, "x": 595.96127271652222, "border_width": 0, "id": 14}, {"node_shape": "dot", "degree": 70, "title": 15, "color": "rgba(256, 230, 25, 1)", "y": 665.30078649520874, "x": 520.19572257995605, "border_width": 0, "id": 15}, {"node_shape": "dot", "degree": 54, "title": 16, "color": "rgba(256, 230, 25, 1)", "y": 584.49029922485352, "x": 574.99587535858154, "border_width": 0, "id": 16}, {"node_shape": "dot", "degree": 2, "title": 17, "color": "rgba(256, 230, 25, 1)", "y": 307.05711245536804, "x": 777.09460258483887, "border_width": 0, "id": 17}, {"node_shape": "dot", "degree": 48, "title": 18, "color": "rgba(256, 230, 25, 1)", "y": 643.51832866668701, "x": 554.11779880523682, "border_width": 0, "id": 18}, {"node_shape": "dot", "degree": 4, "title": 19, "color": "rgba(256, 230, 25, 1)", "y": 744.93902921676636, "x": 428.01642417907715, "border_width": 0, "id": 19}, {"node_shape": "dot", "degree": 13, "title": 20, "color": "rgba(256, 230, 25, 1)", "y": 723.95151853561401, "x": 524.21396970748901, "border_width": 0, "id": 20}, {"node_shape": "dot", "degree": 48, "title": 21, "color": "rgba(256, 230, 25, 1)", "y": 652.35340595245361, "x": 549.88718032836914, "border_width": 0, "id": 21}, {"node_shape": "dot", "degree": 26, "title": 22, "color": "rgba(256, 230, 25, 1)", "y": 492.48462915420532, "x": 584.47688817977905, "border_width": 0, "id": 22}, {"node_shape": "dot", "degree": 98, "title": 23, "color": "rgba(256, 230, 25, 1)", "y": 624.67479705810547, "x": 594.85805034637451, "border_width": 0, "id": 23}, {"node_shape": "dot", "degree": 81, "title": 24, "color": "rgba(256, 230, 25, 1)",  ...
