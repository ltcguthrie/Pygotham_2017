# %% [markdown]
# # Import Libraries

# %%
import matplotlib as mpl
import networkx as nx
import visJS2jupyter.visJS_module
# %matplotlib inline

# %% [markdown]
# ## Karate Club

# %%
G1 = nx.read_gml('../data/karate.gml')

# %%
cc = nx.clustering(G1)
degree = G1.degree()
bc = nx.betweenness_centrality(G1)
nx.set_node_attributes(G1,'clustering_coefficient',cc)
nx.set_node_attributes(G1,'degree',degree)
nx.set_node_attributes(G1,'betweenness_centrality',bc)

# %%
nx.draw(G1)

# %%
nodes = G1.nodes()
edges = G1.edges()

# %%
node_to_color = visJS2jupyter.visJS_module.return_node_to_color(G1,field_to_map='betweenness_centrality',cmap=mpl.cm.spring_r,alpha = 1,
                                                 color_max_frac = .9,color_min_frac = .1)

# set node initial positions using networkx's spring_layout function
pos = nx.spring_layout(G1)

nodes_dict = [{"id":n,"color":node_to_color[n],
               "degree":nx.degree(G1,n),
              "x":pos[n][0]*1000,
              "y":pos[n][1]*1000} for n in nodes
              ]
node_map = dict(zip(nodes,range(len(nodes))))  # map to indices for source/target in edges
edges_dict = [{"source":node_map[edges[i][0]], "target":node_map[edges[i][1]], 
              "color":"gray","title":'test'} for i in range(len(edges))]

# set some network-wide styles
visJS2jupyter.visJS_module.visjs_network(nodes_dict,edges_dict,
                          node_size_multiplier=7,
                          node_size_transform = '',
                          node_color_highlight_border='red',
                          node_color_highlight_background='#D3918B',
                          node_color_hover_border='blue',
                          node_color_hover_background='#8BADD3',
                          node_font_size=25,
                          edge_arrow_to=True,
                          physics_enabled=True,
                          edge_color_highlight='#8A324E',
                          edge_color_hover='#8BADD3',
                          edge_width=3,
                          max_velocity=15,
                          min_velocity=1)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file0"];    frame.runVis([{"node_shape": "dot", "degree": 16, "title": 1, "color": "rgba(256, 25, 230, 1)", "y": 346.26982677174686, "x": 701.57027869939554, "border_width": 0, "id": 1}, {"node_shape": "dot", "degree": 9, "title": 2, "color": "rgba(256, 205, 50, 1)", "y": 497.84060287777311, "x": 688.41567659841576, "border_width": 0, "id": 2}, {"node_shape": "dot", "degree": 10, "title": 3, "color": "rgba(256, 163, 92, 1)", "y": 478.50493851800337, "x": 525.41293305642125, "border_width": 0, "id": 3}, {"node_shape": "dot", "degree": 6, "title": 4, "color": "rgba(256, 224, 31, 1)", "y": 365.48215451246904, "x": 805.93390384927909, "border_width": 0, "id": 4}, {"node_shape": "dot", "degree": 3, "title": 5, "color": "rgba(256, 230, 25, 1)", "y": 188.46084991294904, "x": 921.15914365504045, "border_width": 0, "id": 5}, {"node_shape": "dot", "degree": 4, "title": 6, "color": "rgba(256, 216, 39, 1)", "y": 286.69858376912043, "x": 964.76824344602392, "border_width": 0, "id": 6}, {"node_shape": "dot", "degree": 4, "title": 7, "color": "rgba(256, 216, 39, 1)", "y": 378.49859069923087, "x": 978.22712909335451, "border_width": 0, "id": 7}, {"node_shape": "dot", "degree": 4, "title": 8, "color": "rgba(256, 230, 25, 1)", "y": 534.33088410006678, "x": 859.81285718772585, "border_width": 0, "id": 8}, {"node_shape": "dot", "degree": 5, "title": 9, "color": "rgba(256, 204, 51, 1)", "y": 565.27334311558388, "x": 440.83300528547022, "border_width": 0, "id": 9}, {"node_shape": "dot", "degree": 2, "title": 10, "color": "rgba(256, 230, 25, 1)", "y": 854.7352882079681, "x": 506.6700903952883, "border_width": 0, "id": 10}, {"node_shape": "dot", "degree": 3, "title": 11, "color": "rgba(256, 230, 25, 1)", "y": 102.33675739530246, "x": 863.17016115037495, "border_width": 0, "id": 11}, {"node_shape": "dot", "degree": 1, "title": 12, "color": "rgba(256, 230, 25, 1)", "y": 25.233364020346418, "x": 548.33786807514684, "border_width": 0, "id": 12}, {"node_shape": "dot", "degree": 2, "title": 13, "color": "rgba(256, 230, 25, 1)", "y": 82.889304599999932, "x": 734.64549681921687, "border_width": 0, "id": 13}, {"node_shape": "dot", "degree": 5, "title": 14, "color": "rgba(256, 208, 47, 1)", "y": 564.84238426759748, "x": 680.70562761615827, "border_width": 0, "id": 14}, {"node_shape": "dot", "degree": 2, "title": 15, "color": "rgba(256, 230, 25, 1)", "y": 570.56330603199376, "x": 8.9161008622319056, "border_width": 0, "id": 15}, {"node_shape": "dot", "degree": 2, "title": 16, "color": "rgba(256, 230, 25, 1)", "y": 700.75914766881363, "x": 67.377602647291582, "border_width": 0, "id": 16}, {"node_shape": "dot", "degree": 2, "title": 17, "color": "rgba(256, 230, 25, 1)", "y": 518.21051834959451, "x": 1000.0, "border_width": 0, "id": 17}, {"node_shape": "dot", "degree": 2, "title": 18, "color": "rgba(256, 230, 25, 1)", "y": 635.65686926994272, "x": 662.71805826490424, "border_width": 0, "id": 18}, {"node_shape": "dot", "degree": 2, "title": 19, "color": "rgba(256, 230, 25, 1)", "y": 451.48631950197392, "x": 0.0, "border_width": 0, "id": 19}, {"node_shape": "dot", "degree": 3, "title": 20, "color": "rgba(256, 215, 40, 1)", "y": 729.87254425885862, "x": 662.3995825585547, "border_width": 0, "id": 20}, {"node_shape": "dot", "degree": 2, "title": 21, "color": "rgba(256, 230, 25, 1)", "y": 831.70565743203213, "x": 213.02156152724541, "border_width": 0, "id": 21}, {"node_shape": "dot", "degree": 2, "title": 22, "color": "rgba(256, 230, 25, 1)", "y": 218.39685103723525, "x": 610.5726859107549, "border_width": 0, "id": 22}, {"node_shape": "dot", "degree": 2, "title": 23, "color": "rgba(256, 230, 25, 1)", "y": 781.03535842673227, "x": 131.9640556427955, "border_width": 0, "id": 23}, {"node_shape": "dot", "degree": 5, "title": 24, "color": "rgba(256, 222, 33, 1)", "y": 347.07317035429145, "x": 81.97791558033 ...
